# %% [markdown]
# <a href="https://colab.research.google.com/github/dalsu0222/Computer-Vision-Study/blob/main/average_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# google drive에 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2 as cv
from google.colab.patches import cv_imshow

img = cv.imread('/content/gdrive/MyDrive/MachineVision/opencv-logo-white.png')

blur = cv.blur(img,ksize=(5,5))

cv_imshow(img)
cv_imshow(blur)
# Out:
# <PIL.Image.Image image mode=RGB size=180x238 at 0x7F9AC1E74650>
# <PIL.Image.Image image mode=RGB size=180x238 at 0x7F9AC1E74590>
